# %%
data={}
print(type(data))
# Out:
# <class 'dict'>

# %%
print(-10//3)
# Out:
# -4

# %%
print(-10/3)
# Out:
# -3.3333333333333335

# %%
text="""Conversation-He said, "Aditya's explaination is very good" , i subscribed the channell"""

print(text)
# Out:
# Conversation-He said, "Aditya's explaination is very good" , i subscribed the channell

# %%
print("""Conversation-He said, "Aditya's explaination is very good" , i subscribed the channell""")
# Out:
# Conversation-He said, "Aditya's explaination is very good" , i subscribed the channell

# %%
print(2**3**2)
# Out:
# 512

# %%
name="Shantanu"
name[1:6:-2]
# Out:
# ''

# %%
text = "AdityaKanamadiKakamariAthaniBelagaviKarnataka"
text[2:10:-2]
# Out:
# ''

# %%
text = "AdityaKanamadiKakamariAthaniBelagaviKarnataka"
text[2:10:2]
# Out:
# 'iyKn'

# %%
my_dict={"jay":89,"viru":65,'jay':53}

print(len(my_dict))
# Out:
# 2

# %%
a=[1,5,9]
b=[6,3,7]
c=[7,4,9]

print(list(zip(a,b,c)))
# Out:
# [(1, 6, 7), (5, 3, 4), (9, 7, 9)]

# %%
# 2E3  = 2 * 10^3
# 5E6  = 5 * 10^6

# %%
num=2E3
print(num)
# Out:
# 2000.0

# %%
num1=3E5
print(type(num1))
# Out:
# <class 'float'>

# %%
name = "aditya kanamadi"
name1 = "Aditya kanamadi"

name == name1
# Out:
# False

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65
